# %% [markdown]
# ### 정적 페이지 크롤링하기 - 공공데이터

# %%
from bs4 import BeautifulSoup
import urllib.request as req

# API 요청 후, 응답결과를 xml 파일로 저장
url ="http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"
filename = "forecast.xml"
req.urlretrieve(url, filename)

# 저장된 xml 파일을 읽어드려, 데이터 추출
info = {}
xml = open(filename, 'r', encoding="utf-8").read()
soup = BeautifulSoup(xml, 'xml')

# find_all("location") : <location> 태그들을 읽어옴
for location in soup.find_all("location"):
    city = location.find('city').string         # 도시
    min_t = location.find_all('tmn')            # 최저기온
    max_t = location.find_all('tmx')            # 최고기온
    date = location.find_all('tmEf')            # 날짜시간
    # 최저기온~최고기온 (10~25)
    # wether = [ a.string+"~"+b.string  for a, b in zip(min_t, max_t)]
    # print(f'{city} : {min_t} ~ {max_t}')
    # print(wether)
    wether = []
    # print( len(min_t) )
    # print( len(max_t) )
    # print( len(date) )
    for i in range( len(min_t) ):           # 13
        item = {}
        item['min_t'] = min_t[i]
        item['max_t'] = max_t[i]
        item['date'] = date[i]
        wether.append(item)
    
    # print(city)
    # print(wether)
    
    if not (city in info):
        info[city] = []             # { '서울' : ['22~29'] }
    for data in wether:
        info[city].append(data)     # { '서울' : ['22~29', '22~29', '23~31', '23~31', ...]}
    
print(info)
# Out:
# {'서울': [{'min_t': <tmn>22</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-06-30 00:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-06-30 12:00</tmEf>}, {'min_t': <tmn>23</tmn>, 'max_t': <tmx>31</tmx>, 'date': <tmEf>2023-07-01 00:00</tmEf>}, {'min_t': <tmn>23</tmn>, 'max_t': <tmx>31</tmx>, 'date': <tmEf>2023-07-01 12:00</tmEf>}, {'min_t': <tmn>23</tmn>, 'max_t': <tmx>30</tmx>, 'date': <tmEf>2023-07-02 00:00</tmEf>}, {'min_t': <tmn>23</tmn>, 'max_t': <tmx>30</tmx>, 'date': <tmEf>2023-07-02 12:00</tmEf>}, {'min_t': <tmn>23</tmn>, 'max_t': <tmx>30</tmx>, 'date': <tmEf>2023-07-03 00:00</tmEf>}, {'min_t': <tmn>23</tmn>, 'max_t': <tmx>30</tmx>, 'date': <tmEf>2023-07-03 12:00</tmEf>}, {'min_t': <tmn>23</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-07-04 00:00</tmEf>}, {'min_t': <tmn>23</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-07-04 12:00</tmEf>}, {'min_t': <tmn>23</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-07-05 00:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>28</tmx>, 'date': <tmEf>2023-07-06 00:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-07-07 00:00</tmEf>}], '인천': [{'min_t': <tmn>22</tmn>, 'max_t': <tmx>27</tmx>, 'date': <tmEf>2023-06-30 00:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>27</tmx>, 'date': <tmEf>2023-06-30 12:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>28</tmx>, 'date': <tmEf>2023-07-01 00:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>28</tmx>, 'date': <tmEf>2023-07-01 12:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>27</tmx>, 'date': <tmEf>2023-07-02 00:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>27</tmx>, 'date': <tmEf>2023-07-02 12:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>28</tmx>, 'date': <tmEf>2023-07-03 00:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>28</tmx>, 'date': <tmEf>2023-07-03 12:00</tmEf>}, {'min_t': <tmn>23</tmn>, 'max_t': <tmx>27</tmx>, 'date': <tmEf>2023-07-04 00:00</tmEf>}, {'min_t': <tmn>23</tmn>, 'max_t': <tmx>27</tmx>, 'date': <tmEf>2023-07-04 12:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>26</tmx>, 'date': <tmEf>2023-07-05 00:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>26</tmx>, 'date': <tmEf>2023-07-06 00:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>26</tmx>, 'date': <tmEf>2023-07-07 00:00</tmEf>}], '수원': [{'min_t': <tmn>22</tmn>, 'max_t': <tmx>28</tmx>, 'date': <tmEf>2023-06-30 00:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>28</tmx>, 'date': <tmEf>2023-06-30 12:00</tmEf>}, {'min_t': <tmn>21</tmn>, 'max_t': <tmx>30</tmx>, 'date': <tmEf>2023-07-01 00:00</tmEf>}, {'min_t': <tmn>21</tmn>, 'max_t': <tmx>30</tmx>, 'date': <tmEf>2023-07-01 12:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-07-02 00:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-07-02 12:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-07-03 00:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-07-03 12:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-07-04 00:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-07-04 12:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-07-05 00:00</tmEf>}, {'min_t': <tmn>22</tmn>, 'max_t': <tmx>28</tmx>, 'date': <tmEf>2023-07-06 00:00</tmEf>}, {'min_t': <tmn>21</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-07-07 00:00</tmEf>}], '파주': [{'min_t': <tmn>21</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-06-30 00:00</tmEf>}, {'min_t': <tmn>21</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-06-30 12:00</tmEf>}, {'min_t': <tmn>21</tmn>, 'max_t': <tmx>30</tmx>, 'date': <tmEf>2023-07-01 00:00</tmEf>}, {'min_t': <tmn>21</tmn>, 'max_t': <tmx>30</tmx>, 'date': <tmEf>2023-07-01 12:00</tmEf>}, {'min_t': <tmn>21</tmn>, 'max_t': <tmx>29</tmx>, 'date': <tmEf>2023-07-02 00:00</tmEf>}, {'min_t': <tmn>21</tmn>, 'max_t': <tmx>29</tmx>, 'da ...

# %% [markdown]
# ### 네이버 검색을 통한 거울, 부산, 제주도 날씨 정보 가져오기

# %%
from bs4 import BeautifulSoup
import urllib.request

# 서울 날씨
print('-------------- 서울 날씨')
html_text = urllib.request.urlopen('https://search.naver.com/search.naver?sm=tab_hty.top&where=nexearch&query=' + urllib.parse.quote_plus('서울날씨'))
soup = BeautifulSoup( html_text, 'html.parser' )
temp = soup.select('.temperature_text > strong')
cast = soup.select('.weather.before_slash')
print( temp[0].contents[1] + '(' + cast[0].text + ')' )


# 부산 날씨
print('-------------- 부산 날씨')
html_text = urllib.request.urlopen('https://search.naver.com/search.naver?sm=tab_hty.top&where=nexearch&query=' + urllib.parse.quote_plus('부산날씨'))
soup = BeautifulSoup( html_text, 'html.parser' )
temp = soup.select('.temperature_text > strong')
cast = soup.select('.weather.before_slash')
print( temp[0].contents[1] + '(' + cast[0].text + ')' )

# 제주도 날씨
print('-------------- 제주도 날씨')
html_text = urllib.request.urlopen('https://search.naver.com/search.naver?sm=tab_hty.top&where=nexearch&query=' + urllib.parse.quote_plus('제주도날씨'))
soup = BeautifulSoup( html_text, 'html.parser' )
temp = soup.select('.temperature_text > strong')
cast = soup.select('.weather.before_slash')
print( temp[0].contents[1] + '(' + cast[0].text + ')' )

# %% [markdown]
# ### 버스 이용정보 조회하기 - 서울시 버스 정보

# %%
from bs4 import BeautifulSoup
import urllib.request as req

# 버스번호로 busRouteId 가져오기
busNum = '6628'
# key = 'YMoRqKO2I8ZcrPE7f1kbCGvSnok3IL6QIXgZjcZq4OSy7Lf%2BT0r6dz%2FE0yIqcjUNqL0ICa1vufI33fMKDHCNhg%3D%3D'
key = 'YMoRqKO2I8ZcrPE7f1kbCGvSnok3IL6QIXgZjcZq4OSy7Lf%2BT0r6dz%2FE0yIqcjUNqL0ICa1vufI33fMKDHCNhg%3D%3D'
url1 = 'http://ws.bus.go.kr/api/rest/busRouteInfo/getBusRouteList?serviceKey='+key+'&strSrch='+busNum
res = req.urlopen(url1)

result = res.read().decode('utf-8')

soup = BeautifulSoup( result,'xml' )

busRouteId = None
for itemList in soup.find_all('itemList'):
    busRouteId = itemList.find('busRouteId').string
    busRouteNm = itemList.find('busRouteNm').string
    if busRouteNm == busNum :
        break

print(f'busRouteId : {busRouteId}')
print(f'busRouteNm : {busRouteNm}')


# 노선별 경유 정류소 조회 서비스

url2 = 'http://ws.bus.go.kr/api/rest/busRouteInfo/getStaionByRoute?serviceKey='+key+'&busRouteId='+busRouteId
res = req.urlopen(url2)
result = res.read()
print( result )
soup = BeautifulSoup( result, 'xml' )

# print( soup.prettify() )

busPos = []
for itemList in soup.find_all('itemList'):
    stationNm = itemList.find('stationNm').string
    gpsY = itemList.find('gpsY').string
    gpsX = itemList.find('gpsX').string
    beginTm = itemList.find('beginTm').string
    lastTm = itemList.find('lastTm').string

    busPos.append( (stationNm, gpsY, gpsX, beginTm, lastTm) )

print( busNum + '번 버스 정류소 위치')
for stationNm, lat, lng, beginTm, lastTm in busPos:
    print( stationNm, ':' , lat + ','+ lng + ' (' + beginTm + '~' + lastTm +')' )      # 위도, 경도
# Out:
# busRouteId : 100100305
# busRouteNm : 6628
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?><ServiceResult><comMsgHeader/><msgHeader><headerCd>0</headerCd><headerMsg>\xec\xa0\x95\xec\x83\x81\xec\xa0\x81\xec\x9c\xbc\xeb\xa1\x9c \xec\xb2\x98\xeb\xa6\xac\xeb\x90\x98\xec\x97\x88\xec\x8a\xb5\xeb\x8b\x88\xeb\x8b\xa
# 한국거래소 : 37.523321705,126.9273956702 (04:49~23:56)
# 더현대서울 : 37.5254868228,126.9277728103 (04:54~23:59)
# 여의도환승센터 : 37.5260593379,126.9246697181 (04:56~00:02)
# 여의도공원 : 37.523605,126.920262 (04:59~00:03)
# 경방타임스퀘어.신세계백화점 : 37.5175082319,126.9062396031 (05:00~00:04)
# 김안과병원 : 37.5204160307,126.9028340777 (05:04~00:07)
# 당산동진로아파트 : 37.5213255961,126.8968775442 (05:05~00:11)
# 양남동로타리 : 37.522120309,126.8917785954 (05:06~00:13)
# 양평1동주민센터 : 37.5227527711,126.8881931453 (05:09~00:15)
# 관악고등학교 : 37.523161734,126.8848486189 (05:11~00:17)
# 오목교역.동신한방병원 : 37.5244207004,126.8769371867 (05:13~00:18)
# 목동대학학원 : 37.5249270305,126.8734437529 (05:14~00:19)
# 목동7단지.종로학원 : 37.525671,126.868759 (05:16~00:21)
# 목동역.홍익병원 : 37.5273462899,126.8643441254 (05:19~00:23)
# 홍익병원목동관 : 37.5307277573,126.8640381595 (05:20~00:25)
# 화곡동남부시장 : 37.5318363326,126.858853902 (05:21~00:27)
# 화곡2동주민센터 : 37.5313768831,126.8552226927 (05:24~00:30)
# 서울신정초등학교 : 37.531128,126.852907 (05:26~00:31)
# 화곡8동주민센터 : 37.530822,126.849587 (05:27~00:32)
# 까치산역2번출구 : 37.5317706703,126.8468455507 (05:28~00:33)
# 화곡동백구사 : 37.5325837128,126.8427421149 (05:29~00:34)
# 화곡동대림아파트.화곡중앙시장 : 37.5340439211,126.8383894565 (05:33~00:37)
# 가로공원.나누리병원 : 37.5371786505,126.8362926723 (05:34~00:39)
# 가로공원공영주차장 : 37.536783,126.8332 (05:37~00:40)
# 국민은행신월동지점 : 37.5362149282,126.8296038629 (05:39~00:42)
# 메디힐병원.서울금융고등학교 : 37.5369926272,126.8277768675 (05:39~00:43)
# 신월중학교입구 : 37.5400038442,126.8257669785 (05:41~00:43)
# 외발산신광명마을 : 37.5460645834,126.8215259396 (05:42~00:45)
# 강서면허시험장.메이필드호텔 : 37.5496838966,126.8194959796 (05:44~00:48)
# 강서농수산물도매시장 : 37.55187,126.81998 (05:45~00:49)
# 강서면허시험장.메이필드호텔 : 37.5475298249,126.8203782658 (05:48~00:51)
# 외발산신광명마을 : 37.545958,126.821132 (05:50~00:54)

# %% [markdown]
# ### 네이버 블로그 검색

# %%
import requests
import urllib
import re

# 네이버 애플리케이션 등록 - client_id, client_secret
client_id = 'shmYgYnTj3hr85UQvurE'
client_secret = 'U62MzbiCrv'

query = '영등포 맛집'
query = urllib.parse.quote_plus(query)
display = str(20)

url = 'https://openapi.naver.com/v1/search/blog.json?query=' + query + '&display=' + display

headers = {'X-Naver-Client-Id' : client_id, 'X-Naver-Client-Secret' : client_secret}

res = requests.get( url, headers=headers )
status = res.status_code

if( status == 200):
    data_result = res.json()
    # print(data_result)
    for count, data in enumerate(data_result['items'], 1):
        title = re.sub("</?b>", "", data['title'] )                 # 제목에서 <b> </b> 제거
        description = re.sub("</?b>", "", data['description'] )     # 내용에서 <b> </b> 제거
        print(str(count) + ' : ' + title)
        print('------------------------------')
        print( description )
        print( '블로그명 : ' + data['bloggername'])
        print( 'url : ' + data['link'])

else:
    print('요청 실패 : ' + status)

# %% [markdown]
# ### 네이버 뉴스 기사 검색

# %%
import urllib
import json
import re

# 네이버 애플리케이션 등록 - client_id, client_secret
client_id = 'shmYgYnTj3hr85UQvurE'
client_secret = 'U62MzbiCrv'

query = '올해의 인사'
query = urllib.parse.quote_plus(query)
display = str(20)

url = 'https://openapi.naver.com/v1/search/news.json?query=' + query + '&display=' + display
# headers = {'X-Naver-Client-Id' : client_id, 'X-Naver-Client-Secret' : client_secret}

request = urllib.request.Request(url)
request.add_header('X-Naver-Client-Id', client_id)
request.add_header('X-Naver-Client-Secret', client_secret)

res = urllib.request.urlopen(request)
status = res.getcode()

if( status == 200):
    result = res.read()
    result = json.loads(result)
    
    count = 1
    for data in result['items']:
        print( str(count) + ' : ' + data['title'] )
        print('=========================================')
        print(': ' + data['description'])
        count += 1
    # print(result)

else:
    print('요청 실패 : ' + status)
# Out:
# 1 : [오늘의 DT인] 빌딩과 사랑에 빠졌던 청년 &quot;이젠 뉴욕이 목표&quot;
# =========================================
# : 그는 공인중개업계에서 &apos;샛별&apos;로 등장했다가 단숨에 &apos;혜성&apos;급으로 성장한 유명<b>인사</b>다. 현재는 부동산업계는... 김 대표는 &quot;코로나 팬데믹 한가운데였던 작년 상반기에는 오히려 괜찮았는데, <b>올해</b> 1월은 역대급으로 거래가...
# 2 : 200회 맞은 &apos;유퀴즈&apos;, 지금까지 만난 자기님만 &apos;1205명&apos;
# =========================================
# : 2020년부터 2022년까지는 <b>올해의</b> 브랜드 대상에서 &apos;<b>올해의</b> 프로그램 토크예능 부문&apos;을 3년 연속 수상을... 감사 <b>인사</b>를 전했다. 이어 &quot;&apos;유 퀴즈 온 더 블럭&apos;를 사랑해 주시는 이유는 자기님들의 &apos;이야기&apos;와 그...
# 3 : &apos;재계의 별&apos; 제주 총집결…한국경제 위기돌파 해법 모색
# =========================================
# : 주요 정부부처 장관을 비롯해 석학, 기업 최고경영자 등이 연사로 나선다 대한상의 측은 <b>올해</b> 제주포럼은... 대한상의 관계자는 &quot;과거에는 기업인들과 실제 연관된 경제 관련 부처 위주 <b>인사</b>로 연사를 초청해왔지만...
# 4 : 조심조심하며 살았더니, 100세가 넘었다.
# =========================================
# : &quot;100세까지 사세요&quot; vs &quot;100세 이상 사세요&quot; 나이든 분들에게 흔히 하는 <b>인사</b>말의 &apos;100세까지&apos;를 이제 &apos;100세 이상... 건강수명인의 대표 격으로 <b>올해</b> 103세(1920년생) 김형석 명예교수(연세대 철학과)를 꼽는 사람들이 많다....
# 5 : 김동일 보령시장, &quot;보령형 포용도시로 미래 100년 이끌 것&quot;
# =========================================
# : 김 시장은 <b>인사</b>말에서 &quot;민선 6.7기는 생존을 위한 시간이었다. 지방도시 소멸위기와 산업 대전환이라는... 특히 <b>올해</b> 상반기 전기차 배터리 재사용 및 산업화 기반구축, 메타버스 융합제조사업 실증, 고성능 전기차용...
# 6 : 땀·눈물 범벅된 농성... 10.29 이태원 참사 유가족의 하루 [이태원참사_기록...
# =========================================
# : 간단한 <b>인사</b>가 이어진 후 8시부터는 피켓을 들고 국회 출입문 곳곳으로 흩어졌다. &apos;국민의힘은 이태원 참사... 원래라면 참사 1주기인 <b>올해</b> 10월 29일 특별법을 통과시키고자 했다. 하지만 국회일정 상 도무지 가능하지가...
# 7 : &apos;김연아 출격&apos; 200회 &apos;유퀴즈&apos; 특집..PD &quot;서로 다른 공감 유재석x조세호 덕분...
# =========================================
# : 2020년부터 2022년까지는 <b>올해의</b> 브랜드 대상에서 &apos;<b>올해의</b> 프로그램 토크예능 부문&apos;을 3년 연속 수상을... 감사 <b>인사</b>를 전했다. 이어 &quot;&lt;유 퀴즈&gt;를 사랑해 주시는 이유는 자기님들의 &apos;이야기&apos;와 그 이야기들이 주는...
# 8 : PGA TOUR &amp; LPGA 골프웨어 후원선수 &apos;고진영&apos;, 여자 골프 역대 최장 세계랭킹...
# =========================================
# : 고진영은 <b>올해</b> 3월 HSBC 월드 챔피언십, 5월 파운더스컵 등 LPGA 투어에서 두 차례 우승을 이뤄냈고, 투어... &quot;라며 브랜드에 감사 <b>인사</b>를 전했고, &quot;앞으로도 제가 골프를 하는 데까지 최선을 다해서 좋은 모습...
# 9 : 위기의 부국제, 정상 개최 가능할까…운영위원장 해촉·이사장 사의
# =========================================
# : 통해 <b>올해</b> 영화제 개최에 차질이 없도록 준비를 해 놓고 물러나겠다고 표명하였으나 사태는 그조차 이행이... 부국제는 이용관 이사장 체제 이후 갑작스러운 <b>인사</b>들과 이로 인한 허문영 전 집행위원장의 사임, 연이어...
# 10 : [특별기고] 한미동맹 70주년을 맞아
# =========================================
# : <b>올해</b>는 한국과 미국이 역사성을 지닌 뜻 있는 해다. 한미동맹이 70년을 맞아 윤석열 대통령이 미국 국빈... 워싱턴 의회 연설에서는 미국의 어머니들에게 위로의 메시지를 전하고, 한미 <b>인사</b>들이 함께한 뉴욕...
# 11 : 부산시, 민원 처리 담당자 보호 및 지원 실행계획 수립․시행
# =========================================
# : 일례로 <b>올해</b> 3월 서구의 한 행정복지센터에 60대 남성이 주취 상태에서 공무원에게 휴대전화를 던져 머리를... 실행계획의 주요 내용은 ▲사전 예방 차원에서 민원실 안전시설과 장비 확충, 직무교육과 <b>인사</b>상 우대, 휴식...
# 12 : 민선8기 출범 1주년 김동일 보령시장 &quot;민선 6·7기 돌아보며 보령 미래 100년...
# =========================================
# : 김 시장은 <b>인사</b>말에서 &quot;민선 6·7기는 생존을 위한 시간이었다&quot;며 &quot;지방 도시 소멸 위기와 산업... 특히 <b>올해</b> 상반기 전기차 배터리 재사용 및 산업화 기반구축, 메타버스 융합제조사업 실증, 고성능 전기차용...
# 13 : 새내기 공무원을 응원합니다!
# =========================================
# : 첫번째 <b>올해</b> 9년째를 맞고 있는 공직자 사내대학인 &apos;배워사대&apos; 운영이다. &apos;배워사대&apos;는 2014년도 서귀포시... 그 밖에도 공감인(in), 팀 소통의 날, 찾아가는 <b>인사</b>행정 등 다양한 소통 채널을 통해 기존세대와 신규 공직자가...
# 14 : 전기공사협회 대전시회 &apos;2023년 제2차 운영위원회&apos; 개최
# =========================================
# : 전 회장은 <b>인사</b>말을 통해 &quot;취임 이후 상반기 사업의 성과에 대해 감사드린다&quot;며 &quot;<b>올해</b> 하반기 계획돼 있는 사업을 보다 효율적으로 진행하고자 한다&quot;고 말했다. 이어 &quot;회원의 화합과 단결을 최우선으로 하고 이를...
# 15 : 부산시, ‘민원 처리 담당자 보호 및 지원 실행계획’ 수립․시행
# =========================================
# : <b>올해</b> 3월 서구의 한 행정복지센터에 60대 남성이 주취 상태에서 공무원에게 휴대전화를 던져 머리를 맞히는... 실행계획 주요 내용은 사전 예방 차원에서 민원실 안전시설과 장비 확충, 직무교육과 <b>인사</b>상 우대, 휴식 및...
# 16 : &quot;광주시민축구단 법인카드·경조비 부적정 사용&quot;…감사서 적발
# =========================================
# : 1월부터 <b>올해</b> 2월까지 매달 100만 원씩 법인카드(총 5000만 원)를 사용하게 했다. 이후 A부장은 법인카드로... 이 밖에도 광주FC의 출장여비 집행, 부가가치세 납부·환급세액 정산, 승진 <b>인사</b>, 사무처 직원 인건비 조정...
# 17 : BIFF, 운영위원장 해촉 및 이사장 사임으로 <b>인사</b>잡음 일단락될까
# =========================================
# : <b>인사</b>잡음으로 <b>올해</b> 영화제 개최 여부마저 불투명했던 부산국제영화제(BIFF) 내홍 사태가 이사장 사임과 운영위원장 해촉으로 매듭을 지었으나, 여전히 내부 갈등의 불씨가 남아있다는 지적이다. 27일 BIFF 사무국에 따르면...
# 18 : 금정문화재단, &apos;2023 금샘단오잔치&apos; 성황리에 마무리
# =========================================
# : 덕분에 <b>올해</b> 금샘단오잔치 역시 풍부한 문화 교류의 장이 됐으며, 방문하신 분들 모두 행사장 수칙에 적극적으로 따라주시어 모든 일정을 안전하게 마무리할 수 있었다&quot;라고 감사 <b>인사</b>를 전했다. 또한, &quot;앞으로도...
# 19 : &quot;수강생 벽 허물자 사람들이 몰렸다&quot; 농식품공무원교육원의 &apos;변신&apos;
# =========================================
# : 교육원은 <b>올해</b> &apos;명사 특강&apos; 시리즈를 운영하면서 특강 참석자를 기존 교육생은 물론 인근 광주전남혁신도시... 지역사회의 대표 명품강의로 자리잡을 수 있도록 저명<b>인사</b> 초청 강연을 지속적으로 추진 하겠다&quot;라고 말했다.
# 20 : [더벨]&apos;호시우보&apos;로 항암신약 노리는 대웅제약의 R&amp;D 전략
# =========================================
# : 양사는 셰어드(Shared) 경영으로 요약되는 <b>인사</b>제도를 도입해 항암신약을 포함한 업무 전반의 시너지를 염두에 둔 협업을 이어가고 있다. <b>올해</b> 3월 박수진 대웅제약 ETC 영업본부장이 한올바이오파마의 공동...
